# %%
import pandas as pd
from pandas.io.json import json_normalize
import json
import re


eventlog_df = pd.read_json('cmd_psexec_lsa_secrets_dump_2020-10-1903305471.json', lines=True)

# %%
eventlog_df.head()
# Out:
#                             SourceName              TimeCreated      Hostname  \
# 0           Microsoft-Windows-Eventlog  2020-10-19 03:30:41.104  WORKSTATION5
# 1  Microsoft-Windows-Security-Auditing  2020-10-19 03:30:45.323  WORKSTATION5
# 2  Microsoft-Windows-Security-Auditing  2020-10-19 03:30:45.324  WORKSTATION5
# 3  Microsoft-Windows-Security-Auditing  2020-10-19 03:30:46.251  WORKSTATION5
# 4  Microsoft-Windows-Security-Auditing  2020-10-19 03:30:46.330  WORKSTATION5
#
#     Task   Channel                                            Message  \
# 0    104  Security  The audit log was cleared.\r\nSubject:\r\n\tSe...
# 1  12810  Security  The Windows Filtering Platform has permitted a...
# 2  12810  Security  The Windows Filtering Platform has permitted a...
# 3  13312  Security  A new process has been created.\r\n\r\nCreator...
# 4  12807  Security  An attempt was made to duplicate a handle to a...
#
#    EventID  FilterRTID  SourcePort SourceAddress  ... DestinationPort  \
# 0     1102         NaN         NaN           NaN  ...             NaN
# 1     5158         0.0     58390.0       0.0.0.0  ...             NaN
# 2     5156     69895.0     58390.0   192.168.2.5  ...             NaN
# 3     4688         NaN         NaN           NaN  ...             NaN
# 4     4690         NaN         NaN           NaN  ...             NaN
#
#   SourceIsIpv6  SourceHostname Initiated QueryName QueryStatus QueryResults  \
# 0          NaN             NaN       NaN       NaN         NaN          NaN
# 1          NaN             NaN       NaN       NaN         NaN          NaN
# 2          NaN             NaN       NaN       NaN         NaN          NaN
# 3          NaN             NaN       NaN       NaN         NaN          NaN
# 4          NaN             NaN       NaN       NaN         NaN          NaN
#
#   StartType AccountName  ImagePath
# 0       NaN         NaN        NaN
# 1       NaN         NaN        NaN
# 2       NaN         NaN        NaN
# 3       NaN         NaN        NaN
# 4       NaN         NaN        NaN
#
# [5 rows x 118 columns]

# %% [markdown]
# # Hunting For PsExec
#
# There are various ways to hunt for PsExec useage including looking at evidence of execution artifacts like prefetch, amcache, shim etc. In addition, PsExec often leaves behind trace evidence itself in event logs. PsExec will install itself as a service on a destination host with the service file name recorded as PSEXESVC.exe. The windows System event log will record the service registration as an EventID 7045. Another, helpful way to look for PsExec activity if you have access to an EDR or sysmon is to search for commandlines. For example - the first time a Threat Actor runs PsExec it'll ask to accept the EULA.
#
# The command line will look similar to <font color='red'>PsExec.exe  -accepteula whatever command</font>
# Next, A registry entry is made in the <font color='red'>HKCU\Software\Sysinternals\PsExec\EulaAccepted</font> key which would retain a value of <font color='red'>1'</font>.

# %%
import re

# Replace null values to properly iterate over the dataframe
eventlog_df = eventlog_df.fillna('null')

pattern = r'(psexec)'

for command in eventlog_df['CommandLine']:
    match = re.search(pattern, command, flags=re.IGNORECASE)
    if match:
        print(command)
# Out:
# PsExec.exe  -accepteula -s reg save HKLM\security\policy\secrets C:\Users\wardog\AppData\Local\Temp\secrets
# PsExec.exe  -accepteula -s reg save HKLM\security\policy\secrets C:\Users\wardog\AppData\Local\Temp\secrets

# %% [markdown]
# This search revealed two commands issued by the attacker. The attacker used PsExec accepting the EULA with the -s argument to run with system privs. They save the secrets registry key to the users local profile in appdata\local\temp.

# %% [markdown]
# #### Hunting for service install events with a service file name that contains PSEXESVC

# %%
import pandas as pd

# Select the rows with EventID = 7045 and ServiceName = 'PSEXESVC'
event_df = eventlog_df.loc[(eventlog_df['EventID'] == 7045) & (eventlog_df['ServiceName'] == 'PSEXESVC')]

# Iterate through the rows and print the values
for index, row in event_df.iterrows():
  print(f'Hostname = {row["Hostname"]}')
  print(f'TimeCreated = {row["TimeCreated"]}')
  print(f'EventID = {row["EventID"]}')
  print(f'Message = {row["Message"]}')
  print(f'ParentCommandLine = {row["ParentCommandLine"]}')
  print(f'CommandLine = {row["CommandLine"]}')
# Out:
# Hostname = WORKSTATION5
# TimeCreated = 2020-10-19 03:30:46.416
# EventID = 7045
# Message = A service was installed in the system.
#
# Service Name:  PSEXESVC
# Service File Name:  %SystemRoot%\PSEXESVC.exe
# Service Type:  user mode service
# Service Start Type:  demand start
# Service Account:  LocalSystem
# ParentCommandLine = null
# CommandLine = null

# %% [markdown]
# #### Stacking EventID's
#
# This is a less targeted approach but another way to help identify unexpected or uncommon behavior is to stack evidence. This often times will lead to Threat Actor activity as usually the type of behavior they perform is not consistent with everyday activity from a normal user or on a particular workstation. Sometimes it requires some playing around with.
#
# Stacking is basically counting the number of occurences for a particular dataset. In this case, i'm going to stack all the eventid's containded within the dataframe. All events that have occured less than 10 times will be printed out and then added to a timeline for further review and to aggregate evidence into a format that is easy to read and to help build narrative.

# %%
counts = eventlog_df['EventID'].value_counts()
sort_counts = counts.sort_values()
for value, count in sort_counts.items():
    print(f"EventID: {value} | Occurance: {count}")
# Out:
# EventID: 7045 | Occurance: 1
# EventID: 5140 | Occurance: 1
# EventID: 5145 | Occurance: 1
# EventID: 1102 | Occurance: 1
# EventID: 104 | Occurance: 1
# EventID: 4697 | Occurance: 1
# EventID: 3 | Occurance: 2
# EventID: 22 | Occurance: 2
# EventID: 5158 | Occurance: 3
# EventID: 9 | Occurance: 3
# EventID: 5156 | Occurance: 4
# EventID: 4688 | Occurance: 4
# EventID: 1 | Occurance: 4
# EventID: 4689 | Occurance: 4
# EventID: 4690 | Occurance: 4
# EventID: 4703 | Occurance: 4
# EventID: 4656 | Occurance: 4
# EventID: 4663 | Occurance: 4
# EventID: 5 | Occurance: 4
# EventID: 18 | Occurance: 7
# EventID: 11 | Occurance: 7
# EventID: 17 | Occurance: 7
# EventID: 4658 | Occurance: 8
# EventID: 12 | Occurance: 14
# EventID: 13 | Occurance: 23
# EventID: 10 | Occurance: 38
# EventID: 7 | Occurance: 130

# %%
events_less_than_10 = counts[counts <10].index

stacked_df = eventlog_df[eventlog_df['EventID'].isin(events_less_than_10)]

for _, row in stacked_df.iterrows():
    print(f"EventID: {row['EventID']} - Message: {row['Message']}")
# Out:
# EventID: 1102 - Message: The audit log was cleared.
# Subject:
# 	Security ID:	S-1-5-21-3940915590-64593676-1414006259-500
# 	Account Name:	wardog
# 	Domain Name:	WORKSTATION5
# 	Logon ID:	0xC61D9
# EventID: 5158 - Message: The Windows Filtering Platform has permitted a bind to a local port.
#
# Application Information:
# 	Process ID:		3304
# 	Application Name:	\device\harddiskvolume2\windowsazure\guestagent_2.7.41491.993_2020-10-08_063613\waappagent.exe
#
# Network Information:
# 	Source Address:		0.0.0.0
# 	Source Port:		58390
# 	Protocol:		6
#
# Filter Information:
# 	Filter Run-Time ID:	0
# 	Layer Name:		Resource Assignment
# 	Layer Run-Time ID:	36
# EventID: 5156 - Message: The Windows Filtering Platform has permitted a connection.
#
# Application Information:
# 	Process ID:		3304
# 	Application Name:	\device\harddiskvolume2\windowsazure\guestagent_2.7.41491.993_2020-10-08_063613\waappagent.exe
#
# Network Information:
# 	Direction:		Outbound
# 	Source Address:		192.168.2.5
# 	Source Port:		58390
# 	Destination Address:	168.63.129.16
# 	Destination Port:		80
# 	Protocol:		6
#
# Filter Information:
# 	Filter Run-Time ID:	69895
# 	Layer Name:		Connect
# 	Layer Run-Time ID:	48
# EventID: 4688 - Message: A new process has been created.
#
# Creator Subject:
# 	Security ID:		S-1-5-21-3940915590-64593676-1414006259-500
# 	Account Name:		wardog
# 	Account Domain:		WORKSTATION5
# 	Logon ID:		0xC61D9
#
# Target Subject:
# 	Security ID:		S-1-0-0
# 	Account Name:		-
# 	Account Domain:		-
# 	Logon ID:		0x0
#
# Process Information:
# 	New Process ID:		0x1c58
# 	New Process Name:	C:\Users\wardog\Downloads\PSTools\PsExec.exe
# 	Token Elevation Type:	%%1936
# 	Mandatory Label:		S-1-16-12288
# 	Creator Process ID:	0x850
# 	Creator Process Name:	C:\Windows\System32\cmd.exe
# 	Process Command Line:	PsExec.exe  -accepteula -s reg save HKLM\security\policy\secrets C:\Users\wardog\AppData\Local\Temp\secrets
#
# Token Elevation Type indicates the type of token that was assigned to the new process in accordance with User Account Control policy.
#
# Type 1 is a full token with no privileges removed or groups disabled.  A full token is only used if User Account Control is disabled or if the user is the built-in Administrator account or a service account.
#
# Type 2 is an elevated token with no privileges removed or groups disabled.  An elevated token is used when User Account Control is enabled and the user chooses to start the program using Run as administrator.  An elevated token is also used when an application is configured to always require administrative privilege or to always require maximum privilege, and the user is a member of the Administrators group.
#
# Type 3 is a limited token with administrative privileges removed and administrative groups disabled.  The limited token is used when User Account Control is enabled, the application does not require administrative privilege, and the user does not choose to start the program using Run as administrator.
# EventID: 4690 - Message: An attempt was made to duplicate a handle to an object.
#
# Subject:
# 	Security ID:		S-1-5-21-3940915590-64593676-1414006259-500
# 	Account Name:		wardog
# 	Account Domain:		WORKSTATION5
# 	Logon ID:		0xC61D9
#
# Source Handle Information:
# 	Source Handle ID:	0xfc
# 	Source Process ID:	0x1c58
#
# New Handle Information:
# 	Target Handle ID:	0x1da0
# 	Target Process ID:	0x4
# EventID: 4658 - Message: The handle to an object was closed.
#
# Subject :
# 	Security ID:		S-1-5-21-3940915590-64593676-1414006259-500
# 	Account Name:		wardog
# 	Account Domain:		WORKSTATION5
# 	Logon ID:		0xC61D9
#
# Object:
# 	Object Server:		Security
# 	Handle ID:		0x1da0
#
# Process Information:
# 	Process ID:		0x1c58
# 	Process Name:		C:\Users\wardog\Downloads\PSTools\PsExec.exe
# EventID: 4656 - Message: A handle to an object was requested.
#
# Subject:
# 	Security ID:		S-1-5-21-3940915590-64593676-1414006259-500
# 	Account Name:		wardog
# 	Account Domain:		WORKSTATION5
# 	Logon ID:		0xC61D9
#
# Object:
# 	Object Server:		Security
# 	Object Type:		Key
# 	Object Name:		\REGISTRY\MACHINE\SYSTEM\ControlSet001\Control\Lsa
# 	Handle ID:		0xfc
# 	Resource Attributes:	-
#
# Process Information:
# 	Process ID:		0x1c58
# 	Process Name:		C:\Users\wardog\Downloads\PSTools\PsExec.exe
#
# Access Request Information:
# 	Transaction ID:		{00000000-0000-0000-0000-000000000000}
# 	Accesses:		Query key value
#
# 	Access Reasons:		-
# 	Access Mask:		0x1
# 	Privileges Used for Access Check:	-
# 	Restricted SID Count:	0
# EventID: 4663 - Message: An attempt was made to access an object.
#
# Subject:
# 	Security ID:		S-1-5-21-3940915590-64593676-1414006259-500
# 	Account Name:		wardog
# 	Account Domain:		WORKSTATION5
# 	Logon ID:		0xC61D9
#
# Object:
# 	Object Server:		Security
# 	Object Type:		Key
# 	Object Name:		\REGISTRY\MACHINE\SYSTEM\ControlSet001\Control\Lsa
# 	Handle ID:		0xfc
# 	Resource Attributes:	-
#
# Process Information:
# 	Process ID:		0x1c58
# 	Process Name:		C:\Users\wardog\Downloads\PSTools\PsExec.exe
#
# Access Request Information:
# 	Accesses:		Query key value
#
# 	Access Mask:		0x1
# EventID: 4658 - Message: The handle to an object was closed.
#
# Subject :
# 	Security ID:		S-1-5-21-3940915590-64593676-1414006259-500
# 	Account Name:		wardog
# 	Account Domain:		WORKSTATION5
# 	Logon ID:		0xC61D9
#
# Object:
# 	Object Server:		Security
# 	Handle ID:		0xfc
#
# Process Information:
# 	Process ID:		0x1c58
# 	Process Name:		C:\Users\wardog\Downloads\PSTools\PsExec.exe
# EventID: 4697 - Message: A service was installed in the system.
#
# Subject:
# 	Security ID:		S-1-5-21-3940915590-64593676-1414006259-500
# 	Account Name:		wardog
# 	Account Domain:		WORKSTATION5
# 	Logon ID:		0xC61D9
#
# Service Information:
# 	Service Name: 		PSEXESVC
# 	Service File Name:	%SystemRoot%\PSEXESVC.exe
# 	Service Type: 		0x10
# 	Service Start Type:	3
# 	Service Account: 		LocalSystem
# EventID: 4690 - Message: An attempt was made to duplicate a handle to an object.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Source Handle Information:
# 	Source Handle ID:	0xbbc
# 	Source Process ID:	0x2cc
#
# New Handle Information:
# 	Target Handle ID:	0x39ec
# 	Target Process ID:	0x4
# EventID: 4658 - Message: The handle to an object was closed.
#
# Subject :
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Object:
# 	Object Server:		Security
# 	Handle ID:		0x39ec
#
# Process Information:
# 	Process ID:		0x2cc
# 	Process Name:		C:\Windows\System32\services.exe
# EventID: 4656 - Message: A handle to an object was requested.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Object:
# 	Object Server:		Security
# 	Object Type:		Key
# 	Object Name:		\REGISTRY\MACHINE\SYSTEM\ControlSet001\Control\Session Manager\Environment
# 	Handle ID:		0xbbc
# 	Resource Attributes:	-
#
# Process Information:
# 	Process ID:		0x2cc
# 	Process Name:		C:\Windows\System32\services.exe
#
# Access Request Information:
# 	Transaction ID:		{00000000-0000-0000-0000-000000000000}
# 	Accesses:		READ_CONTROL
# 				Query key value
# 				Enumerate sub-keys
# 				Notify about changes to keys
#
# 	Access Reasons:		-
# 	Access Mask:		0x20019
# 	Privileges Used for Access Check:	-
# 	Restricted SID Count:	0
# EventID: 4663 - Message: An attempt was made to access an object.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Object:
# 	Object Server:		Security
# 	Object Type:		Key
# 	Object Name:		\REGISTRY\MACHINE\SYSTEM\ControlSet001\Control\Session Manager\Environment
# 	Handle ID:		0xbbc
# 	Resource Attributes:	-
#
# Process Information:
# 	Process ID:		0x2cc
# 	Process Name:		C:\Windows\System32\services.exe
#
# Access Request Information:
# 	Accesses:		Query key value
#
# 	Access Mask:		0x1
# EventID: 4658 - Message: The handle to an object was closed.
#
# Subject :
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Object:
# 	Object Server:		Security
# 	Handle ID:		0xbbc
#
# Process Information:
# 	Process ID:		0x2cc
# 	Process Name:		C:\Windows\System32\services.exe
# EventID: 4688 - Message: A new process has been created.
#
# Creator Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Target Subject:
# 	Security ID:		S-1-0-0
# 	Account Name:		-
# 	Account Domain:		-
# 	Logon ID:		0x0
#
# Process Information:
# 	New Process ID:		0x5b4
# 	New Process Name:	C:\Windows\PSEXESVC.exe
# 	Token Elevation Type:	%%1936
# 	Mandatory Label:		S-1-16-16384
# 	Creator Process ID:	0x2cc
# 	Creator Process Name:	C:\Windows\System32\services.exe
# 	Process Command Line:	C:\windows\PSEXESVC.exe
#
# Token Elevation Type indicates the type of token that was assigned to the new process in accordance with User Account Control policy.
#
# Type 1 is a full token with no privileges removed or groups disabled.  A full token is only used if User Account Control is disabled or if the user is the built-in Administrator account or a service account.
#
# Type 2 is an elevated token with no privileges removed or groups disabled.  An elevated token is used when User Account Control is enabled and the user chooses to start the program using Run as administrator.  An elevated token is also used when an application is configured to always require administrative privilege or to always require maximum privilege, and the user is a member of the Administrators group.
#
# Type 3 is a limited token with administrative privileges removed and administrative groups disabled.  The limited token is used when User Account Control is enabled, the application does not require administrative privilege, and the user does not choose to start the program using Run as administrator.
# EventID: 4690 - Message: An attempt was made to duplicate a handle to an object.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Source Handle Information:
# 	Source Handle ID:	0xdc
# 	Source Process ID:	0x5b4
#
# New Handle Information:
# 	Target Handle ID:	0x39ec
# 	Target Process ID:	0x4
# EventID: 4658 - Message: The handle to an object was closed.
#
# Subject :
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Object:
# 	Object Server:		Security
# 	Handle ID:		0x39ec
#
# Process Information:
# 	Process ID:		0x5b4
# 	Process Name:		C:\Windows\PSEXESVC.exe
# EventID: 4656 - Message: A handle to an object was requested.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Object:
# 	Object Server:		Security
# 	Object Type:		Key
# 	Object Name:		\REGISTRY\MACHINE\SYSTEM\ControlSet001\Control\Lsa
# 	Handle ID:		0xdc
# 	Resource Attributes:	-
#
# Process Information:
# 	Process ID:		0x5b4
# 	Process Name:		C:\Windows\PSEXESVC.exe
#
# Access Request Information:
# 	Transaction ID:		{00000000-0000-0000-0000-000000000000}
# 	Accesses:		Query key value
#
# 	Access Reasons:		-
# 	Access Mask:		0x1
# 	Privileges Used for Access Check:	-
# 	Restricted SID Count:	0
# EventID: 4663 - Message: An attempt was made to access an object.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Object:
# 	Object Server:		Security
# 	Object Type:		Key
# 	Object Name:		\REGISTRY\MACHINE\SYSTEM\ControlSet001\Control\Lsa
# 	Handle ID:		0xdc
# 	Resource Attributes:	-
#
# Process Information:
# 	Process ID:		0x5b4
# 	Process Name:		C:\Windows\PSEXESVC.exe
#
# Access Request Information:
# 	Accesses:		Query key value
#
# 	Access Mask:		0x1
# EventID: 4658 - Message: The handle to an object was closed.
#
# Subject :
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Object:
# 	Object Server:		Security
# 	Handle ID:		0xdc
#
# Process Information:
# 	Process ID:		0x5b4
# 	Process Name:		C:\Windows\PSEXESVC.exe
# EventID: 4703 - Message: A token right was adjusted.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Target Account:
# 	Security ID:		S-1-0-0
# 	Account Name:		wardog
# 	Account Domain:		WORKSTATION5
# 	Logon ID:		0xC61D9
#
# Process Information:
# 	Process ID:		0x2f4
# 	Process Name:		C:\Windows\System32\lsass.exe
#
# Enabled Privileges:
# 			SeIncreaseQuotaPrivilege
# 			SeSecurityPrivilege
# 			SeTakeOwnershipPrivilege
# 			SeLoadDriverPrivilege
# 			SeSystemProfilePrivilege
# 			SeSystemtimePrivilege
# 			SeProfileSingleProcessPrivilege
# 			SeIncreaseBasePriorityPrivilege
# 			SeCreatePagefilePrivilege
# 			SeBackupPrivilege
# 			SeRestorePrivilege
# 			SeShutdownPrivilege
# 			SeDebugPrivilege
# 			SeSystemEnvironmentPrivilege
# 			SeRemoteShutdownPrivilege
# 			SeUndockPrivilege
# 			SeManageVolumePrivilege
# 			SeIncreaseWorkingSetPrivilege
# 			SeTimeZonePrivilege
# 			SeCreateSymbolicLinkPrivilege
# 			SeDelegateSessionUserImpersonatePrivilege
#
# Disabled Privileges:
# 			-
# EventID: 5158 - Message: The Windows Filtering Platform has permitted a bind to a local port.
#
# Application Information:
# 	Process ID:		4
# 	Application Name:	System
#
# Network Information:
# 	Source Address:		::
# 	Source Port:		58391
# 	Protocol:		6
#
# Filter Information:
# 	Filter Run-Time ID:	0
# 	Layer Name:		Resource Assignment
# 	Layer Run-Time ID:	38
# EventID: 5156 - Message: The Windows Filtering Platform has permitted a connection.
#
# Application Information:
# 	Process ID:		4
# 	Application Name:	System
#
# Network Information:
# 	Direction:		Outbound
# 	Source Address:		fe80::90e:17af:263c:5209
# 	Source Port:		58391
# 	Destination Address:	fe80::90e:17af:263c:5209
# 	Destination Port:		445
# 	Protocol:		6
#
# Filter Information:
# 	Filter Run-Time ID:	65889
# 	Layer Name:		Connect
# 	Layer Run-Time ID:	50
# EventID: 5156 - Message: The Windows Filtering Platform has permitted a connection.
#
# Application Information:
# 	Process ID:		4
# 	Application Name:	System
#
# Network Information:
# 	Direction:		Inbound
# 	Source Address:		fe80::90e:17af:263c:5209
# 	Source Port:		58391
# 	Destination Address:	fe80::90e:17af:263c:5209
# 	Destination Port:		445
# 	Protocol:		6
#
# Filter Information:
# 	Filter Run-Time ID:	65887
# 	Layer Name:		Receive/Accept
# 	Layer Run-Time ID:	46
# EventID: 4703 - Message: A token right was adjusted.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Target Account:
# 	Security ID:		S-1-0-0
# 	Account Name:		wardog
# 	Account Domain:		WORKSTATION5
# 	Logon ID:		0xC61D9
#
# Process Information:
# 	Process ID:		0x2f4
# 	Process Name:		C:\Windows\System32\lsass.exe
#
# Enabled Privileges:
# 			SeIncreaseQuotaPrivilege
# 			SeSecurityPrivilege
# 			SeTakeOwnershipPrivilege
# 			SeLoadDriverPrivilege
# 			SeSystemProfilePrivilege
# 			SeSystemtimePrivilege
# 			SeProfileSingleProcessPrivilege
# 			SeIncreaseBasePriorityPrivilege
# 			SeCreatePagefilePrivilege
# 			SeBackupPrivilege
# 			SeRestorePrivilege
# 			SeShutdownPrivilege
# 			SeDebugPrivilege
# 			SeSystemEnvironmentPrivilege
# 			SeRemoteShutdownPrivilege
# 			SeUndockPrivilege
# 			SeManageVolumePrivilege
# 			SeIncreaseWorkingSetPrivilege
# 			SeTimeZonePrivilege
# 			SeCreateSymbolicLinkPrivilege
# 			SeDelegateSessionUserImpersonatePrivilege
#
# Disabled Privileges:
# 			-
# EventID: 5140 - Message: A network share object was accessed.
#
# Subject:
# 	Security ID:		S-1-5-21-3940915590-64593676-1414006259-500
# 	Account Name:		wardog
# 	Account Domain:		WORKSTATION5
# 	Logon ID:		0xC61D9
#
# Network Information:
# 	Object Type:		File
# 	Source Address:		fe80::90e:17af:263c:5209
# 	Source Port:		58391
#
# Share Information:
# 	Share Name:		\\*\IPC$
# 	Share Path:
#
# Access Request Information:
# 	Access Mask:		0x1
# 	Accesses:		ReadData (or ListDirectory)
#
#
# EventID: 5145 - Message: A network share object was checked to see whether client can be granted desired access.
#
# Subject:
# 	Security ID:		S-1-5-21-3940915590-64593676-1414006259-500
# 	Account Name:		wardog
# 	Account Domain:		WORKSTATION5
# 	Logon ID:		0xC61D9
#
# Network Information:
# 	Object Type:		File
# 	Source Address:		fe80::90e:17af:263c:5209
# 	Source Port:		58391
#
# Share Information:
# 	Share Name:		\\*\IPC$
# 	Share Path:
# 	Relative Target Name:	PSEXESVC
#
# Access Request Information:
# 	Access Mask:		0x12019F
# 	Accesses:		READ_CONTROL
# 				SYNCHRONIZE
# 				ReadData (or ListDirectory)
# 				WriteData (or AddFile)
# 				AppendData (or AddSubdirectory or CreatePipeInstance)
# 				ReadEA
# 				WriteEA
# 				ReadAttributes
# 				WriteAttributes
#
# Access Check Results:
# 	-
#
# EventID: 4688 - Message: A new process has been created.
#
# Creator Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Target Subject:
# 	Security ID:		S-1-0-0
# 	Account Name:		-
# 	Account Domain:		-
# 	Logon ID:		0x0
#
# Process Information:
# 	New Process ID:		0x338
# 	New Process Name:	C:\Windows\System32\reg.exe
# 	Token Elevation Type:	%%1936
# 	Mandatory Label:		S-1-16-16384
# 	Creator Process ID:	0x5b4
# 	Creator Process Name:	C:\Windows\PSEXESVC.exe
# 	Process Command Line:	"reg" save HKLM\security\policy\secrets C:\Users\wardog\AppData\Local\Temp\secrets
#
# Token Elevation Type indicates the type of token that was assigned to the new process in accordance with User Account Control policy.
#
# Type 1 is a full token with no privileges removed or groups disabled.  A full token is only used if User Account Control is disabled or if the user is the built-in Administrator account or a service account.
#
# Type 2 is an elevated token with no privileges removed or groups disabled.  An elevated token is used when User Account Control is enabled and the user chooses to start the program using Run as administrator.  An elevated token is also used when an application is configured to always require administrative privilege or to always require maximum privilege, and the user is a member of the Administrators group.
#
# Type 3 is a limited token with administrative privileges removed and administrative groups disabled.  The limited token is used when User Account Control is enabled, the application does not require administrative privilege, and the user does not choose to start the program using Run as administrator.
# EventID: 4688 - Message: A new process has been created.
#
# Creator Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Target Subject:
# 	Security ID:		S-1-0-0
# 	Account Name:		-
# 	Account Domain:		-
# 	Logon ID:		0x0
#
# Process Information:
# 	New Process ID:		0x2304
# 	New Process Name:	C:\Windows\System32\conhost.exe
# 	Token Elevation Type:	%%1936
# 	Mandatory Label:		S-1-16-16384
# 	Creator Process ID:	0x338
# 	Creator Process Name:	C:\Windows\System32\reg.exe
# 	Process Command Line:	\??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
#
# Token Elevation Type indicates the type of token that was assigned to the new process in accordance with User Account Control policy.
#
# Type 1 is a full token with no privileges removed or groups disabled.  A full token is only used if User Account Control is disabled or if the user is the built-in Administrator account or a service account.
#
# Type 2 is an elevated token with no privileges removed or groups disabled.  An elevated token is used when User Account Control is enabled and the user chooses to start the program using Run as administrator.  An elevated token is also used when an application is configured to always require administrative privilege or to always require maximum privilege, and the user is a member of the Administrators group.
#
# Type 3 is a limited token with administrative privileges removed and administrative groups disabled.  The limited token is used when User Account Control is enabled, the application does not require administrative privilege, and the user does not choose to start the program using Run as administrator.
# EventID: 4690 - Message: An attempt was made to duplicate a handle to an object.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Source Handle Information:
# 	Source Handle ID:	0x80
# 	Source Process ID:	0x2304
#
# New Handle Information:
# 	Target Handle ID:	0x23bc
# 	Target Process ID:	0x4
# EventID: 4658 - Message: The handle to an object was closed.
#
# Subject :
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Object:
# 	Object Server:		Security
# 	Handle ID:		0x23bc
#
# Process Information:
# 	Process ID:		0x2304
# 	Process Name:		C:\Windows\System32\conhost.exe
# EventID: 4656 - Message: A handle to an object was requested.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Object:
# 	Object Server:		Security
# 	Object Type:		Key
# 	Object Name:		\REGISTRY\MACHINE\SYSTEM\ControlSet001\Control\Lsa
# 	Handle ID:		0x80
# 	Resource Attributes:	-
#
# Process Information:
# 	Process ID:		0x2304
# 	Process Name:		C:\Windows\System32\conhost.exe
#
# Access Request Information:
# 	Transaction ID:		{00000000-0000-0000-0000-000000000000}
# 	Accesses:		Query key value
#
# 	Access Reasons:		-
# 	Access Mask:		0x1
# 	Privileges Used for Access Check:	-
# 	Restricted SID Count:	0
# EventID: 4663 - Message: An attempt was made to access an object.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Object:
# 	Object Server:		Security
# 	Object Type:		Key
# 	Object Name:		\REGISTRY\MACHINE\SYSTEM\ControlSet001\Control\Lsa
# 	Handle ID:		0x80
# 	Resource Attributes:	-
#
# Process Information:
# 	Process ID:		0x2304
# 	Process Name:		C:\Windows\System32\conhost.exe
#
# Access Request Information:
# 	Accesses:		Query key value
#
# 	Access Mask:		0x1
# EventID: 4658 - Message: The handle to an object was closed.
#
# Subject :
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Object:
# 	Object Server:		Security
# 	Handle ID:		0x80
#
# Process Information:
# 	Process ID:		0x2304
# 	Process Name:		C:\Windows\System32\conhost.exe
# EventID: 4703 - Message: A token right was adjusted.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Target Account:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Process Information:
# 	Process ID:		0x338
# 	Process Name:		C:\Windows\System32\reg.exe
#
# Enabled Privileges:
# 			SeBackupPrivilege
#
# Disabled Privileges:
# 			-
# EventID: 4689 - Message: A process has exited.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Process Information:
# 	Process ID:	0x338
# 	Process Name:	C:\Windows\System32\reg.exe
# 	Exit Status:	0x0
# EventID: 4689 - Message: A process has exited.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Process Information:
# 	Process ID:	0x2304
# 	Process Name:	C:\Windows\System32\conhost.exe
# 	Exit Status:	0x0
# EventID: 4703 - Message: A token right was adjusted.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Target Account:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Process Information:
# 	Process ID:		0x2cc
# 	Process Name:		C:\Windows\System32\services.exe
#
# Enabled Privileges:
# 			SeBackupPrivilege
# 			SeRestorePrivilege
# 			SeSecurityPrivilege
# 			SeTakeOwnershipPrivilege
#
# Disabled Privileges:
# 			-
# EventID: 4689 - Message: A process has exited.
#
# Subject:
# 	Security ID:		S-1-5-18
# 	Account Name:		WORKSTATION5$
# 	Account Domain:		WORKGROUP
# 	Logon ID:		0x3E7
#
# Process Information:
# 	Process ID:	0x5b4
# 	Process Name:	C:\Windows\PSEXESVC.exe
# 	Exit Status:	0x0
# EventID: 4689 - Message: A process has exited.
#
# Subject:
# 	Security ID:		S-1-5-21-3940915590-64593676-1414006259-500
# 	Account Name:		wardog
# 	Account Domain:		WORKSTATION5
# 	Logon ID:		0xC61D9
#
# Process Information:
# 	Process ID:	0x1c58
# 	Process Name:	C:\Users\wardog\Downloads\PSTools\PsExec.exe
# 	Exit Status:	0x0
# EventID: 5158 - Message: The Windows Filtering Platform has permitted a bind to a local port.
#
# Application Information:
# 	Process ID:		3428
# 	Application Name:	\device\harddiskvolume2\windowsazure\guestagent_2.7.41491.993_2020-10-08_063613\guestagent\windowsazureguestagent.exe
#
# Network Information:
# 	Source Address:		0.0.0.0
# 	Source Port:		58392
# 	Protocol:		6
#
# Filter Information:
# 	Filter Run-Time ID:	0
# 	Layer Name:		Resource Assignment
# 	Layer Run-Time ID:	36
# EventID: 5156 - Message: The Windows Filtering Platform has permitted a connection.
#
# Application Information:
# 	Process ID:		3428
# 	Application Name:	\device\harddiskvolume2\windowsazure\guestagent_2.7.41491.993_2020-10-08_063613\guestagent\windowsazureguestagent.exe
#
# Network Information:
# 	Direction:		Outbound
# 	Source Address:		192.168.2.5
# 	Source Port:		58392
# 	Destination Address:	168.63.129.16
# 	Destination Port:		80
# 	Protocol:		6
#
# Filter Information:
# 	Filter Run-Time ID:	69895
# 	Layer Name:		Connect
# 	Layer Run-Time ID:	48
# EventID: 11 - Message: File created:
# RuleName: -
# UtcTime: 2020-10-19 07:30:42.056
# ProcessGuid: {39e4a257-f133-5f8b-1c00-000000000700}
# ProcessId: 1260
# Image: C:\windows\System32\svchost.exe
# TargetFilename: C:\Windows\ServiceState\EventLog\Data\lastalive1.dat
# CreationUtcTime: 2020-10-18 07:40:33.283
# EventID: 1 - Message: Process Create:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.251
# ProcessGuid: {39e4a257-40a6-5f8d-a005-000000000700}
# ProcessId: 7256
# Image: C:\Users\wardog\Downloads\PSTools\PsExec.exe
# FileVersion: 2.2
# Description: Execute processes remotely
# Product: Sysinternals PsExec
# Company: Sysinternals - www.sysinternals.com
# OriginalFileName: psexec.c
# CommandLine: PsExec.exe  -accepteula -s reg save HKLM\security\policy\secrets C:\Users\wardog\AppData\Local\Temp\secrets
# CurrentDirectory: C:\Users\wardog\Downloads\PSTools\
# User: WORKSTATION5\wardog
# LogonGuid: {39e4a257-f1ac-5f8b-d961-0c0000000000}
# LogonId: 0xC61D9
# TerminalSessionId: 2
# IntegrityLevel: High
# Hashes: SHA1=E50D9E3BD91908E13A26B3E23EDEAF577FB3A095,MD5=27304B246C7D5B4E149124D5F93C5B01,SHA256=3337E3875B05E0BFBA69AB926532E3F179E8CFBF162EBB60CE58A0281437A7EF,IMPHASH=C1E59519B5E5D84AF07AFA6F5A8625F1
# ParentProcessGuid: {39e4a257-402f-5f8d-9905-000000000700}
# ParentProcessId: 2128
# ParentImage: C:\Windows\System32\cmd.exe
# ParentCommandLine: "C:\windows\system32\cmd.exe"
# EventID: 11 - Message: File created:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.400
# ProcessGuid: {39e4a257-40a6-5f8d-a005-000000000700}
# ProcessId: 7256
# Image: C:\Users\wardog\Downloads\PSTools\PsExec.exe
# TargetFilename: C:\Windows\PSEXESVC.exe
# CreationUtcTime: 2020-10-19 07:30:46.400
# EventID: 1 - Message: Process Create:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.435
# ProcessGuid: {39e4a257-40a6-5f8d-a105-000000000700}
# ProcessId: 1460
# Image: C:\Windows\PSEXESVC.exe
# FileVersion: 2.2
# Description: PsExec Service
# Product: Sysinternals PsExec
# Company: Sysinternals
# OriginalFileName: psexesvc.exe
# CommandLine: C:\windows\PSEXESVC.exe
# CurrentDirectory: C:\windows\system32\
# User: NT AUTHORITY\SYSTEM
# LogonGuid: {39e4a257-f131-5f8b-e703-000000000000}
# LogonId: 0x3E7
# TerminalSessionId: 0
# IntegrityLevel: System
# Hashes: SHA1=A17C21B909C56D93D978014E63FB06926EAEA8E7,MD5=75B55BB34DAC9D02740B9AD6B6820360,SHA256=141B2190F51397DBD0DFDE0E3904B264C91B6F81FEBC823FF0C33DA980B69944,IMPHASH=67012475995FB9027F4511245B57DDEA
# ParentProcessGuid: {39e4a257-f131-5f8b-0b00-000000000700}
# ParentProcessId: 716
# ParentImage: C:\Windows\System32\services.exe
# ParentCommandLine: C:\windows\system32\services.exe
# EventID: 17 - Message: Pipe Created:
# RuleName: -
# EventType: CreatePipe
# UtcTime: 2020-10-19 07:30:46.478
# ProcessGuid: {39e4a257-40a6-5f8d-a105-000000000700}
# ProcessId: 1460
# PipeName: \PSEXESVC
# Image: C:\windows\PSEXESVC.exe
# EventID: 18 - Message: Pipe Connected:
# RuleName: -
# EventType: ConnectPipe
# UtcTime: 2020-10-19 07:30:46.619
# ProcessGuid: {39e4a257-f121-5f8b-0100-000000000700}
# ProcessId: 4
# PipeName: \PSEXESVC
# Image: System
# EventID: 17 - Message: Pipe Created:
# RuleName: -
# EventType: CreatePipe
# UtcTime: 2020-10-19 07:30:46.635
# ProcessGuid: {39e4a257-40a6-5f8d-a105-000000000700}
# ProcessId: 1460
# PipeName: \PSEXESVC-WORKSTATION5-7256-stdin
# Image: C:\windows\PSEXESVC.exe
# EventID: 17 - Message: Pipe Created:
# RuleName: -
# EventType: CreatePipe
# UtcTime: 2020-10-19 07:30:46.635
# ProcessGuid: {39e4a257-40a6-5f8d-a105-000000000700}
# ProcessId: 1460
# PipeName: \PSEXESVC-WORKSTATION5-7256-stdout
# Image: C:\windows\PSEXESVC.exe
# EventID: 17 - Message: Pipe Created:
# RuleName: -
# EventType: CreatePipe
# UtcTime: 2020-10-19 07:30:46.635
# ProcessGuid: {39e4a257-40a6-5f8d-a105-000000000700}
# ProcessId: 1460
# PipeName: \PSEXESVC-WORKSTATION5-7256-stderr
# Image: C:\windows\PSEXESVC.exe
# EventID: 18 - Message: Pipe Connected:
# RuleName: -
# EventType: ConnectPipe
# UtcTime: 2020-10-19 07:30:46.650
# ProcessGuid: {39e4a257-40a6-5f8d-a005-000000000700}
# ProcessId: 7256
# PipeName: \PSEXESVC-WORKSTATION5-7256-stdin
# Image: C:\Users\wardog\Downloads\PSTools\PsExec.exe
# EventID: 18 - Message: Pipe Connected:
# RuleName: -
# EventType: ConnectPipe
# UtcTime: 2020-10-19 07:30:46.650
# ProcessGuid: {39e4a257-40a6-5f8d-a005-000000000700}
# ProcessId: 7256
# PipeName: \PSEXESVC-WORKSTATION5-7256-stdout
# Image: C:\Users\wardog\Downloads\PSTools\PsExec.exe
# EventID: 18 - Message: Pipe Connected:
# RuleName: -
# EventType: ConnectPipe
# UtcTime: 2020-10-19 07:30:46.650
# ProcessGuid: {39e4a257-40a6-5f8d-a005-000000000700}
# ProcessId: 7256
# PipeName: \PSEXESVC-WORKSTATION5-7256-stderr
# Image: C:\Users\wardog\Downloads\PSTools\PsExec.exe
# EventID: 17 - Message: Pipe Created:
# RuleName: -
# EventType: CreatePipe
# UtcTime: 2020-10-19 07:30:46.650
# ProcessGuid: {39e4a257-40a6-5f8d-a105-000000000700}
# ProcessId: 1460
# PipeName: <Anonymous Pipe>
# Image: C:\windows\PSEXESVC.exe
# EventID: 18 - Message: Pipe Connected:
# RuleName: -
# EventType: ConnectPipe
# UtcTime: 2020-10-19 07:30:46.650
# ProcessGuid: {39e4a257-40a6-5f8d-a105-000000000700}
# ProcessId: 1460
# PipeName: <Anonymous Pipe>
# Image: C:\windows\PSEXESVC.exe
# EventID: 17 - Message: Pipe Created:
# RuleName: -
# EventType: CreatePipe
# UtcTime: 2020-10-19 07:30:46.650
# ProcessGuid: {39e4a257-40a6-5f8d-a105-000000000700}
# ProcessId: 1460
# PipeName: <Anonymous Pipe>
# Image: C:\windows\PSEXESVC.exe
# EventID: 18 - Message: Pipe Connected:
# RuleName: -
# EventType: ConnectPipe
# UtcTime: 2020-10-19 07:30:46.650
# ProcessGuid: {39e4a257-40a6-5f8d-a105-000000000700}
# ProcessId: 1460
# PipeName: <Anonymous Pipe>
# Image: C:\windows\PSEXESVC.exe
# EventID: 17 - Message: Pipe Created:
# RuleName: -
# EventType: CreatePipe
# UtcTime: 2020-10-19 07:30:46.650
# ProcessGuid: {39e4a257-40a6-5f8d-a105-000000000700}
# ProcessId: 1460
# PipeName: <Anonymous Pipe>
# Image: C:\windows\PSEXESVC.exe
# EventID: 18 - Message: Pipe Connected:
# RuleName: -
# EventType: ConnectPipe
# UtcTime: 2020-10-19 07:30:46.650
# ProcessGuid: {39e4a257-40a6-5f8d-a105-000000000700}
# ProcessId: 1460
# PipeName: <Anonymous Pipe>
# Image: C:\windows\PSEXESVC.exe
# EventID: 1 - Message: Process Create:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.660
# ProcessGuid: {39e4a257-40a6-5f8d-a205-000000000700}
# ProcessId: 824
# Image: C:\Windows\System32\reg.exe
# FileVersion: 10.0.18362.476 (WinBuild.160101.0800)
# Description: Registry Console Tool
# Product: Microsoft® Windows® Operating System
# Company: Microsoft Corporation
# OriginalFileName: reg.exe
# CommandLine: "reg" save HKLM\security\policy\secrets C:\Users\wardog\AppData\Local\Temp\secrets
# CurrentDirectory: C:\windows\system32\
# User: NT AUTHORITY\SYSTEM
# LogonGuid: {39e4a257-f131-5f8b-e703-000000000000}
# LogonId: 0x3E7
# TerminalSessionId: 0
# IntegrityLevel: System
# Hashes: SHA1=EB3B03616EEE42F16D0703F64DE23E7E34FE8524,MD5=601BDDF7691C5AF626A5719F1D7E35F1,SHA256=4ED2A27860FA154415F65452FF1F94BD6AF762982E2F3470030C504DC3C8A354,IMPHASH=BE482BE427FE212CFEF2CDA0E61F19AC
# ParentProcessGuid: {39e4a257-40a6-5f8d-a105-000000000700}
# ParentProcessId: 1460
# ParentImage: C:\Windows\PSEXESVC.exe
# ParentCommandLine: C:\windows\PSEXESVC.exe
# EventID: 9 - Message: RawAccessRead detected:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.650
# ProcessGuid: {39e4a257-f121-5f8b-0100-000000000700}
# ProcessId: 4
# Image: System
# Device: \Device\HarddiskVolume1
# EventID: 9 - Message: RawAccessRead detected:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.650
# ProcessGuid: {39e4a257-f121-5f8b-0100-000000000700}
# ProcessId: 4
# Image: System
# Device: \Device\HarddiskVolume3
# EventID: 9 - Message: RawAccessRead detected:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.650
# ProcessGuid: {39e4a257-f121-5f8b-0100-000000000700}
# ProcessId: 4
# Image: System
# Device: \Device\HarddiskVolume2
# EventID: 1 - Message: Process Create:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.673
# ProcessGuid: {39e4a257-40a6-5f8d-a305-000000000700}
# ProcessId: 8964
# Image: C:\Windows\System32\conhost.exe
# FileVersion: 10.0.18362.1 (WinBuild.160101.0800)
# Description: Console Window Host
# Product: Microsoft® Windows® Operating System
# Company: Microsoft Corporation
# OriginalFileName: CONHOST.EXE
# CommandLine: \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# CurrentDirectory: C:\windows
# User: NT AUTHORITY\SYSTEM
# LogonGuid: {39e4a257-f131-5f8b-e703-000000000000}
# LogonId: 0x3E7
# TerminalSessionId: 0
# IntegrityLevel: System
# Hashes: SHA1=11996F32DD85863A8C3BFF6D520F788A9211C8F7,MD5=C5E9B1D1103EDCEA2E408E9497A5A88F,SHA256=BAF97B2A629723947539CFF84E896CD29565AB4BB68B0CEC515EB5C5D6637B69,IMPHASH=F8DD0EF565DE87D97ABF9C62EA63EC21
# ParentProcessGuid: {39e4a257-40a6-5f8d-a205-000000000700}
# ParentProcessId: 824
# ParentImage: C:\Windows\System32\reg.exe
# ParentCommandLine: "reg" save HKLM\security\policy\secrets C:\Users\wardog\AppData\Local\Temp\secrets
# EventID: 11 - Message: File created:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.713
# ProcessGuid: {39e4a257-40a6-5f8d-a205-000000000700}
# ProcessId: 824
# Image: C:\windows\system32\reg.exe
# TargetFilename: C:\Users\wardog\AppData\Local\Temp\secrets
# CreationUtcTime: 2020-10-19 07:30:46.713
# EventID: 11 - Message: File created:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.713
# ProcessGuid: {39e4a257-40a6-5f8d-a205-000000000700}
# ProcessId: 824
# Image: C:\windows\system32\reg.exe
# TargetFilename: C:\Users\wardog\AppData\Local\Temp\secrets
# CreationUtcTime: 2020-10-19 07:30:46.713
# EventID: 5 - Message: Process terminated:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.728
# ProcessGuid: {39e4a257-40a6-5f8d-a205-000000000700}
# ProcessId: 824
# Image: C:\Windows\System32\reg.exe
# EventID: 5 - Message: Process terminated:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.728
# ProcessGuid: {39e4a257-40a6-5f8d-a305-000000000700}
# ProcessId: 8964
# Image: C:\Windows\System32\conhost.exe
# EventID: 11 - Message: File created:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.744
# ProcessGuid: {39e4a257-f133-5f8b-3100-000000000700}
# ProcessId: 1556
# Image: C:\windows\system32\svchost.exe
# TargetFilename: C:\Windows\Prefetch\REG.EXE-E7E8BD26.pf
# CreationUtcTime: 2020-10-18 07:20:56.567
# EventID: 5 - Message: Process terminated:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.744
# ProcessGuid: {39e4a257-40a6-5f8d-a105-000000000700}
# ProcessId: 1460
# Image: C:\Windows\PSEXESVC.exe
# EventID: 11 - Message: File created:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.744
# ProcessGuid: {39e4a257-f133-5f8b-3100-000000000700}
# ProcessId: 1556
# Image: C:\windows\system32\svchost.exe
# TargetFilename: C:\Windows\Prefetch\PSEXESVC.EXE-7F956DAF.pf
# CreationUtcTime: 2020-10-19 07:30:46.744
# EventID: 5 - Message: Process terminated:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.853
# ProcessGuid: {39e4a257-40a6-5f8d-a005-000000000700}
# ProcessId: 7256
# Image: C:\Users\wardog\Downloads\PSTools\PsExec.exe
# EventID: 11 - Message: File created:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.853
# ProcessGuid: {39e4a257-f133-5f8b-3100-000000000700}
# ProcessId: 1556
# Image: C:\windows\system32\svchost.exe
# TargetFilename: C:\Windows\Prefetch\PSEXEC.EXE-197EFCC8.pf
# CreationUtcTime: 2020-10-19 07:30:46.853
# EventID: 3 - Message: Network connection detected:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.319
# ProcessGuid: {39e4a257-f121-5f8b-0100-000000000700}
# ProcessId: 4
# Image: System
# User: NT AUTHORITY\SYSTEM
# Protocol: tcp
# Initiated: true
# SourceIsIpv6: true
# SourceIp: fe80:0:0:0:90e:17af:263c:5209
# SourceHostname: -
# SourcePort: 58391
# SourcePortName: -
# DestinationIsIpv6: true
# DestinationIp: fe80:0:0:0:90e:17af:263c:5209
# DestinationHostname: -
# DestinationPort: 445
# DestinationPortName: -
# EventID: 3 - Message: Network connection detected:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.319
# ProcessGuid: {39e4a257-f121-5f8b-0100-000000000700}
# ProcessId: 4
# Image: System
# User: NT AUTHORITY\SYSTEM
# Protocol: tcp
# Initiated: false
# SourceIsIpv6: true
# SourceIp: fe80:0:0:0:90e:17af:263c:5209
# SourceHostname: -
# SourcePort: 58391
# SourcePortName: -
# DestinationIsIpv6: true
# DestinationIp: fe80:0:0:0:90e:17af:263c:5209
# DestinationHostname: -
# DestinationPort: 445
# DestinationPortName: -
# EventID: 22 - Message: Dns query:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.099
# ProcessGuid: {00000000-0000-0000-0000-000000000000}
# ProcessId: 7256
# QueryName: WORKSTATION5
# QueryStatus: 0
# QueryResults: 192.168.2.5;
# Image: <unknown process>
# EventID: 22 - Message: Dns query:
# RuleName: -
# UtcTime: 2020-10-19 07:30:46.325
# ProcessGuid: {39e4a257-f133-5f8b-1a00-000000000700}
# ProcessId: 1240
# QueryName: WORKSTATION5
# QueryStatus: 0
# QueryResults: fe80::90e:17af:263c:5209;::ffff:192.168.2.5;
# Image: C:\Windows\System32\svchost.exe
# EventID: 104 - Message: The System log file was cleared.
# EventID: 7045 - Message: A service was installed in the system.
#
# Service Name:  PSEXESVC
# Service File Name:  %SystemRoot%\PSEXESVC.exe
# Service Type:  user mode service
# Service Start Type:  demand start
# Service Account:  LocalSystem

# %%
#get stacked event_logs into timeline
writer = pd.ExcelWriter('timeline.xlsx', engine='openpyxl', mode='a')

stacked_df[['Hostname', 'TimeCreated', 'EventID', 'Message', 'ParentCommandLine', 'CommandLine']].to_excel(writer, index=False, header=False, sheet_name='Stacked_Events')

writer.save()

# %% [markdown]
# #### Stacking CommandLines
#
# Just like I did above I'm going to perform another stack analysis but this time on commandlines.

# %%
commandLineCounts = eventlog_df['CommandLine'].value_counts() 
print(commandLineCounts)
# Out:
# null                                                                                                           278
# PsExec.exe  -accepteula -s reg save HKLM\security\policy\secrets C:\Users\wardog\AppData\Local\Temp\secrets      2
# C:\windows\PSEXESVC.exe                                                                                          2
# "reg" save HKLM\security\policy\secrets C:\Users\wardog\AppData\Local\Temp\secrets                               2
# \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1                                                          2
# Name: CommandLine, dtype: int64

# %%
filteredForCommandLines = eventlog_df[eventlog_df['CommandLine'].notnull()]

for index, row in filteredForCommandLines.iterrows():
    hostname = row['Hostname']
    time_created = row['TimeCreated']
    event_id = row['EventID']
    message = row['Message']
    parent_command_line = row['ParentCommandLine']
    command_line = row['CommandLine']
    print(f'Hostname: {hostname}, TimeCreated: {time_created}, ParentCommandLine: {parent_command_line}, CommandLine: {command_line}')

# %%
#Get these into the timeline
writer = pd.ExcelWriter('timeline.xlsx', engine='openpyxl', mode='a')

filteredForCommandLines = eventlog_df[eventlog_df['CommandLine'].notnull()]

filteredForCommandLines[['Hostname', 'TimeCreated', 'EventID', 'Message', 'ParentCommandLine', 'CommandLine']].to_excel(writer, index=False, header=False, sheet_name="Stacked_CommandLines")

writer.save()

# %%
#get the entire dataframe into the spreadsheet.
writer = pd.ExcelWriter('timeline.xlsx', engine='openpyxl', mode='a')

eventlog_df.to_excel(writer, index=False, header=False, sheet_name="DataFrame")

writer.save()
